# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

from datetime import datetime

# %matplotlib inline

# %% [markdown]
# # GitHub Users Analysis

# %%
categories = {
    'watch': ['WatchEvent'],
    'interact': ['CommitCommentEvent', 'GollumEvent', 'PullRequestReviewCommentEvent','IssuesEvent', 
                 'IssueCommentEvent'], #'ForkEvent'],
    'contribute': ['CreateEvent', 'DeleteEvent', 'PullRequestEvent', 'PushEvent','ReleaseEvent', 'MemberEvent'],
    'fork': 'ForkEvent'
}

cat_list = ['contribute','interact','watch']
cat_list_2 = cat_list + ['fork']

def define_category(event):
    for c in categories.keys():
        if event in categories[c]:
            return c

def get_perc_distr(row, clist):
    sum_a = sum([row[c] for c in clist])
    
    norm_row = {}
    for c in clist:
        norm_row[c] = float(row[c])/sum_a
        
    return pd.Series(norm_row)

# %%
path = './'

# %% [markdown]
# # Users behavior

# %% [markdown]
# Analysis of users and how they interact inside target projects based on historical data of GitHub activities in **2015** and **2016**.

# %%
# data import
a18 = pd.read_csv(path + 'target_a_2018.csv', parse_dates=['crearte'])

# %%
a16.head()
# Out:
#     source    target              event           timestamp
# 0   289412    507775  IssueCommentEvent 2016-01-18 23:00:00
# 1   546885  29028775  IssueCommentEvent 2016-01-18 23:00:04
# 2   463737  45717250   PullRequestEvent 2016-01-18 23:00:06
# 3  8566911  23096959  IssueCommentEvent 2016-01-18 23:00:13
# 4   827131   7691631  IssueCommentEvent 2016-01-18 23:00:16

# %%
a16['event'].unique()
# Out:
# array(['IssueCommentEvent', 'PullRequestEvent', 'WatchEvent',
#        'PullRequestReviewCommentEvent', 'DeleteEvent', 'PushEvent',
#        'IssuesEvent', 'ForkEvent', 'CreateEvent', 'CommitCommentEvent',
#        'ReleaseEvent', 'MemberEvent', 'GollumEvent'], dtype=object)

# %%
a15 = pd.read_csv(path + 'activity_2015.csv', parse_dates=['timestamp'])
a15['event'].unique()
# Out:
# array(['IssueCommentEvent', 'WatchEvent', 'ForkEvent', 'IssuesEvent',
#        'PullRequestReviewCommentEvent', 'CommitCommentEvent', 'PushEvent',
#        'PullRequestEvent', 'GollumEvent', 'CreateEvent', 'DeleteEvent',
#        'ReleaseEvent', 'MemberEvent', 'PublicEvent'], dtype=object)

# %%
# basic statistics
# print '2015'
# print '#activities: {}'.format(a15.shape[0])
# print '#users: {}'.format(len(a15['source'].unique()))
# print 'Time Window: {} , {}'.format(min(a15['timestamp']), max(a15['timestamp']))

# %%
# basic statistics
print '2016'
print '#activities: {}'.format(a16.shape[0])
print '#users: {}'.format(len(a16['source'].unique()))
print 'Time Window: {} , {}'.format(min(a16['timestamp']), max(a16['timestamp']))
# Out:
# 2016
# #activities: 3275390
# #users: 721187
# Time Window: 2016-01-01 00:00:23 , 2016-12-31 23:59:37

# %%
# a = pd.concat([a15, a16])
a = a16
a.head()
# Out:
#     source    target              event           timestamp
# 0   289412    507775  IssueCommentEvent 2016-01-18 23:00:00
# 1   546885  29028775  IssueCommentEvent 2016-01-18 23:00:04
# 2   463737  45717250   PullRequestEvent 2016-01-18 23:00:06
# 3  8566911  23096959  IssueCommentEvent 2016-01-18 23:00:13
# 4   827131   7691631  IssueCommentEvent 2016-01-18 23:00:16

# %%
a.shape
# Out:
# (3275390, 4)

# %%
a['cat'] = a['event'].apply(lambda x: define_category(x))

# %%
a['cat'].value_counts()
# Out:
# interact      1547971
# watch         1126540
# contribute     317122
# fork           283757
# Name: cat, dtype: int64

# %% [markdown]
# ## Activities Distribution

# %%
cat = a.groupby(by=['target', 'cat'])[['source']].count().reset_index()
cat.columns = ['project', 'category', '#events']

# %%
distr = cat.pivot(index='project', columns='category', values='#events').fillna(0)
distr.boxplot(figsize=(20,10))
plt.title('Overall number of activities across projects - 2016')

plt.figure(2, figsize=(20,10))
distr.apply(lambda x: get_perc_distr(x, cat_list), axis=1).boxplot()
#plt.title('Percentage of activities in each category - 2016')
font = 15
plt.ylabel('proportion of activities', fontsize=font)
plt.xticks(fontsize=font);
plt.yticks(fontsize=font);

# %%
distr.apply(lambda x: get_perc_distr(x, cat_list), axis=1).describe()
# Out:
#        contribute   interact      watch
# count   97.000000  97.000000  97.000000
# mean     0.080710   0.429568   0.489722
# std      0.077553   0.190098   0.231517
# min      0.002176   0.040225   0.021061
# 25%      0.030180   0.273018   0.289314
# 50%      0.054319   0.421712   0.501982
# 75%      0.105137   0.581221   0.690227
# max      0.481459   0.901875   0.949220

# %%
u_cat = a.groupby(by=['source', 'cat'])[['target']].count().reset_index()
u_cat.columns = ['user', 'category', '#events']
u_cat.head()
# Out:
#    user    category  #events
# 0     4    interact        7
# 1     7  contribute        1
# 2     7    interact        9
# 3    17       watch        1
# 4    21        fork        1

# %%
u_distr = u_cat.pivot(index='user', columns='category', values='#events').fillna(0)
u_distr.head()
# Out:
# category  contribute  fork  interact  watch
# user
# 4                0.0   0.0       7.0    0.0
# 7                1.0   0.0       9.0    0.0
# 17               0.0   0.0       0.0    1.0
# 21               0.0   1.0       1.0    0.0
# 22               1.0   1.0       1.0    0.0

# %%
norm_u_distr = u_distr.div(u_distr.sum(axis=1), axis=0)
norm_u_distr.head()
# Out:
# category  contribute      fork  interact  watch
# user
# 4           0.000000  0.000000  1.000000    0.0
# 7           0.100000  0.000000  0.900000    0.0
# 17          0.000000  0.000000  0.000000    1.0
# 21          0.000000  0.500000  0.500000    0.0
# 22          0.333333  0.333333  0.333333    0.0

# %%
import matplotlib as mpl

print(mpl.rcParams['agg.path.chunksize'])
# Out:
# 30000

# %%
mpl.rcParams['agg.path.chunksize'] = 30000

# %%
print(mpl.rcParams['agg.path.chunksize'])
# Out:
# 30000

# %%
norm_u_distr.shape
# Out:
# (721187, 4)

# %%
font = 18

plt.figure(figsize=(30, 12))

N = 721187
x = range(N)
y = norm_u_distr.sample(N).sort_values(by=['contribute', 'interact','fork'], ascending=False)

plt.fill_between(x, 0, y["contribute"], label='contribute')
plt.fill_between(x, y["contribute"], y["interact"]+y["contribute"], label='interact')
plt.fill_between(x, y["contribute"]+y["interact"], y["interact"]+y["contribute"]+y["fork"], label='fork')
plt.fill_between(x, y["interact"] + y['contribute']+y["fork"], y["watch"]+y["interact"]+y['contribute']+y["fork"], 
                                                                                         label='watch')
plt.grid()
plt.legend(fontsize='xx-large')
plt.xlabel('users', fontsize=font)
plt.ylabel('proportion of activities', fontsize=font)
plt.xticks(fontsize=font);
plt.yticks(fontsize=font);

# %%
N_contrib = norm_u_distr[norm_u_distr['contribute'] > 0].shape[0]
print(N_contrib, float(N_contrib)/N)
# Out:
# (19214, 0.02664218850312055)

# %%
N_interact = norm_u_distr[(norm_u_distr['contribute'] == 0) & (norm_u_distr['interact'] > 0)].shape[0]
print(N_interact, float(N_interact)/N)
# Out:
# (106889, 0.14821259950609203)

# %%
N_fork = norm_u_distr[(norm_u_distr['contribute'] == 0) & 
                      (norm_u_distr['interact'] == 0) & 
                      (norm_u_distr['fork'] > 0)].shape[0]
print(N_fork, float(N_fork)/N)
# Out:
# (176801, 0.24515278284273012)

# %%
N_fork_only = norm_u_distr[(norm_u_distr['contribute'] == 0) & 
                      (norm_u_distr['interact'] == 0) & 
                      (norm_u_distr['fork'] > 0) &
                      (norm_u_distr['watch'] == 0)].shape[0]
print(N_fork_only, float(N_fork_only)/N)
# Out:
# (113930, 0.1579756706651673)

# %%
N_watch = norm_u_distr[(norm_u_distr['contribute'] == 0) & 
                      (norm_u_distr['interact'] == 0) & 
                      (norm_u_distr['fork'] == 0) &
                      (norm_u_distr['watch'] > 0)].shape[0]
print(N_watch, float(N_watch)/N)
# Out:
# (418283, 0.5799924291480573)

# %%
N_w_f = norm_u_distr[(norm_u_distr['contribute'] == 0) & 
                      (norm_u_distr['interact'] == 0) & 
                      (norm_u_distr['fork'] > 0) &
                      (norm_u_distr['watch'] > 0)].shape[0]
print(N_w_f, float(N_w_f)/N)
# Out:
# (62871, 0.08717711217756283)

# %%
font = 18

plt.figure(figsize=(30, 12))


y = norm_u_distr[norm_u_distr['contribute']>0].sort_values(by=['contribute','interact','fork'], ascending=False)
x = range(y.shape[0])

plt.fill_between(x, 0, y["contribute"], label='contribute')
plt.fill_between(x, y["contribute"], y["interact"]+y["contribute"], label='interact')
plt.fill_between(x, y["contribute"]+y["interact"], y["interact"]+y["contribute"]+y["fork"], label='fork')
plt.fill_between(x, y["interact"] + y['contribute']+y["fork"], y["watch"]+y["interact"]+y['contribute']+y["fork"], 
                                                                                         label='watch')
plt.grid()
plt.legend(fontsize='xx-large')
plt.xlabel('users', fontsize=font)
plt.ylabel('proportion of activities', fontsize=font)
plt.xticks(fontsize=font);
plt.yticks(fontsize=font);

# %% [markdown]
# ## Activities distribution month by month

# %%
start_d = datetime(2015, 1, 1)
next_d = start_d + pd.DateOffset(months=1)

cat_distr = {'contribute': [], 'interact': [], 'watch': [], 'other': []}
for _ in range(24):
    
    curr_a = a[(a['timestamp'] >= start_d) & (a['timestamp'] < next_d)]

    cat = curr_a.groupby(by=['target', 'cat'])[['source']].count().reset_index()
    cat.columns = ['project', 'category', '#events']

    
    distr = cat.pivot(index='project', columns='category', values='#events').fillna(0)
    norm_distr = distr.apply(lambda x: get_perc_distr(x, cat_list), axis=1)
    for c in cat_list:
        cat_distr[c].append(norm_distr[c].values)
    
    start_d = next_d
    next_d = start_d + pd.DateOffset(months=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-5d6de4900bc3> in <module>()
#      14     norm_distr = distr.apply(lambda x: get_perc_distr(x, cat_list), axis=1)
#      15     for c in cat_list:
# ---> 16         cat_distr[c].append(norm_distr[c].values)
#      17
#      18     start_d = next_d
#
# /home/brambilla/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /home/brambilla/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /home/brambilla/.local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# /home/brambilla/.local/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /home/brambilla/.local/lib/python2.7/site-packages/pandas/core/indexes/numeric.pyc in get_loc(self, key, method, tolerance)
#     417             pass
#     418         return super(Float64Index, self).get_loc(key, method=method,
# --> 419                                                  tolerance=tolerance)
#     420
#     421     @cache_readonly
#
# /home/brambilla/.local/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    3064                 return self._engine.get_loc(key)
#    3065             except KeyError:
# -> 3066                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3067
#    3068         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'contribute'

# %%
base = datetime(2015, 1, 1)
date_list = [base + pd.DateOffset(months=x) for x in range(0, 24)]
date_labels = [x.strftime('%b %Y') for x in date_list]

# %%
plt.figure(figsize=(24, 10))
plt.boxplot(cat_distr['contribute'])
plt.xticks(range(1, 25), date_labels, rotation=45)
plt.title('CONTRIBUTE distribution month by month for 100 target projects')

# %%
plt.figure(figsize=(24, 10))
plt.boxplot(cat_distr['interact']);

# %%
plt.figure(figsize=(24, 10))
plt.boxplot(cat_distr['watch']);

# %%
plt.figure(figsize=(24, 10))
plt.boxplot(cat_distr['other']);

# %% [markdown]
# ## Activities Distribution inside projects

# %%
counts = a.groupby(by=['target', 'cat'])[['source']].count().reset_index()
counts.columns = ['project', 'category', '#events']
counts.head()
# Out:
#    project    category  #events
# 0     8514  contribute     9648
# 1     8514    interact    32702
# 2     8514       watch     6488
# 3    65252  contribute     2866
# 4    65252    interact    12795

# %%
cmap = cm.get_cmap('autumn')
counts.pivot(index='project', columns='category', values='#events').fillna(0)\
                                .plot(kind='bar', stacked=True, 
                                      figsize=(20,10), title='Category distribution in 2016', cmap=cmap)

# %%
activity_counts = a.groupby(by=['target', 'event'])[['source']].count().reset_index()
activity_counts.columns = ['project', 'event', 'freq']
activity_counts.head()
# Out:
#    project               event   freq
# 0     8514  CommitCommentEvent    530
# 1     8514         CreateEvent    109
# 2     8514         DeleteEvent    137
# 3     8514           ForkEvent   3652
# 4     8514   IssueCommentEvent  20776

# %%
sort_events = ['CreateEvent', 'DeleteEvent', 'PullRequestEvent', 'PushEvent','ReleaseEvent', 'MemberEvent',
              'CommitCommentEvent', 'GollumEvent', 'PullRequestReviewCommentEvent','IssuesEvent', 'IssueCommentEvent',
                'ForkEvent', 'WatchEvent']

# %%
stacked_activity = activity_counts.pivot(index='project', columns='event', values='freq').fillna(0)
stacked_activity = stacked_activity[sort_events]

# %%
cmap = cm.get_cmap('Spectral')
stacked_activity.plot(kind='bar', stacked=True, figsize=(20,10), title='Events distribution in 2016', cmap=cmap)

# %%
elist = []

for e in categories.values():
    elist  = elist + e

# %%
stacked_activity_norm = activity_counts.pivot(index='project', columns='event', values='freq').fillna(0)\
        .apply(lambda x: get_perc_distr(x, elist), axis=1)

# sort columns
stacked_activity_norm = stacked_activity_norm[sort_events]

# %%
# sort projects
stacked_activity_norm = stacked_activity_norm.sort_values(by=['WatchEvent'])

# %%
stacked_activity_norm.plot(kind='bar', stacked=True, figsize=(20,10), cmap=cmap) # title='Events distribution in 2016'

font = 15
plt.grid()
plt.legend(fontsize='large')
plt.xlabel('projects', fontsize=font)
plt.ylabel('proportion of activities', fontsize=font)
plt.xticks(fontsize=font-2);
plt.yticks(fontsize=font);

# %%
aggregated_activity = activity_counts.pivot(index='project', columns='event', values='freq').fillna(0)\
        .drop('WatchEvent', axis=1).apply(lambda x: get_perc_distr(x, elist[:-1]), axis=1)

# sort columns
aggregated_activity = aggregated_activity[sort_events[:-1]]

# %%
aggregated_activity.boxplot(figsize=(20, 10), rot=90)

font = 15
plt.xlabel('events', fontsize=font)
plt.ylabel('proportion of activities', fontsize=font)
plt.xticks(fontsize=font-2);
plt.yticks(fontsize=font);

# %%
p_sample = a[a['target'] == 20580498]

# %%
p_sample.shape
# Out:
# (401171, 5)

# %%
events = p_sample.groupby(by=['target', 'event'])[['source']].count().reset_index()
events.columns = ['project', 'event', '#events']
events.pivot(index='project', columns='event', values='#events').plot(kind='bar', figsize=(16,10))

# %%
start_d = datetime(2015, 1, 1)
next_d = start_d + pd.DateOffset(months=1)

df = pd.DataFrame()
for _ in range(24):
    
    curr_a = p_sample[(p_sample['timestamp'] >= start_d) & (p_sample['timestamp'] < next_d)]

    events = curr_a.groupby(by=['target', 'event'])[['source']].count().reset_index()
    events.columns = ['project', 'event', '#events']
    row = events.pivot(index='project', columns='event', values='#events')
    row['date'] = start_d.strftime('%b %Y')
    row = row.set_index('date')
    
    df = df.append(row)
    
    start_d = next_d
    next_d = start_d + pd.DateOffset(months=1)
# Out:
# /home/brambilla/.local/lib/python2.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
w = 0.35

df[['IssueCommentEvent']].plot(kind='bar', figsize=(16,10), ax=ax1, color='tab:brown', position=1, width=w)
df[['IssuesEvent']].plot(kind='bar', figsize=(16,10), ax=ax2, color='tab:pink', position=0, width=w)

# %%
df[['IssueCommentEvent', 'IssuesEvent']].plot(kind='bar', color=['tab:brown', 'tab:pink'],
                                              figsize=(16,10), grid=True,subplots=True,sharex=True);

# %%
df[[ 'PullRequestEvent']].plot(kind='bar', figsize=(16,10), grid=True);

# %% [markdown]
# ## Project timeseries

# %%
p_ts = p_sample.drop(['source'], axis=1).set_index('timestamp')
releases = p_ts[p_ts['event'] == 'ReleaseEvent']

# %%
p_ts.head()

# %%
releases.head()

# %%
all_ts = pd.DataFrame()
for c in ['contribute', 'interact', 'watch', 'other']:
    ts = p_ts[p_ts['cat'] == c].groupby(pd.Grouper(freq='D'))[['target']].count()
    ts.columns = [c]
    
    all_ts = pd.concat([all_ts, ts], axis=1)

# %%
all_ts.fillna(0).plot(figsize=(16, 8))

#for r in releases.index:
#    plt.axvline(r.date(), linestyle='--', color='black', linewidth=0.5)
